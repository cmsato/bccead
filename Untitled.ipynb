# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
import numpy as np

# %%
a = np.arange(-100,100.1,0.1)

# %%
print(a)
# Out:
# [-100.   -99.9  -99.8 ...,   99.8   99.9  100. ]

# %%
b = np.sin(a)

# %%
print(b)
# Out:
# [ 0.50636564  0.58992416  0.66758835 ..., -0.66758835 -0.58992416
#  -0.50636564]

# %%
plt.plot(a,b);
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.xlabel("tempo" );

# %%
plt.ylabel("seno");

# %%
plt.title("Sinal analógico");

# %%
plt.axis('equal')
# Out:
# (-100.0, 100.0, -1.0, 1.0)

# %%
plt.grid(True)
